# %%
import requests
import math
import statsmodels.api as sm
import seaborn as sns
import numpy as np
from scipy.stats import norm as nrm, mstats

from itertools import groupby
from datetime import datetime as dt

from repos import *
from utils import *
from perform_mktests import *
from perform_sonarqube_analysis import *

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt', 'plot', 'types']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
repos = get_repos()

# %% [markdown]
# # RQ1 and RQ2

# %%
perform_the_analysis(repos)
perform_mktests(repos)
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Project Name (TD - trend, h, p, z) (normalized TD - trend, h, p, z)
# scikit-learn ('no trend', False, 1.0, 0) ('no trend', False, 1.0, 0)
# scikit-image ('no trend', False, 1.0, 0) ('no trend', False, 1.0, 0)
# skll ('no trend', False, 1.0, 0) ('no trend', False, 1.0, 0)
# theano ('no trend', False, 1.0, 0) ('no trend', False, 1.0, 0)
# pytorch ('no trend', False, 1.0, 0.0) ('no trend', False, 1.0, 0.0)
# pyhsmm ('no trend', False, 1.0, 0) ('no trend', False, 1.0, 0)
# pybrain ('no trend', False, 1.0, 0) ('no trend', False, 0.5509849875850934, -0.5962847939999439)
# pattern ('no trend', False, 1.0, 0) ('no trend', False, 1.0, 0)
# nltk ('no trend', False, 1.0, 0) ('no trend', False, 1.0, 0)
# nilearn ('no trend', False, 1.0, 0) ('no trend', False, 1.0, 0)
# milk ('no trend', False, 1.0, 0) ('no trend', False, 1.0, 0)
# gensim ('no trend', False, 1.0, 0.0) ('no trend', False, 1.0, 0.0)
# deap ('no trend', False, 1.0, 0) ('no trend', False, 1.0, 0)
