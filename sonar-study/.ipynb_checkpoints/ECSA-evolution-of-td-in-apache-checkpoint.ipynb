# %%
import requests
import math
import statsmodels.api as sm
import seaborn as sns
import numpy as np
from scipy.stats import norm as nrm, mstats

from itertools import groupby
from datetime import datetime as dt

from repos import *
from utils import *
from perform_mktests import *
from perform_sonarqube_analysis import *
# Out:
# /usr/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt', 'types', 'plot']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
repos = get_repos()

# %% [markdown]
# # RQ1 and RQ2

# %%
perform_the_analysis(repos)
perform_mktests(repos)
# Out:
# Project Name (TD - trend, h, p, z) (normalized TD - trend, h, p, z)
# scikit-learn ('increasing', True, 2.9326910677696105e-06, 4.675478427088236) ('no trend', False, 0.6614159170078631, -0.43795912116108715)
