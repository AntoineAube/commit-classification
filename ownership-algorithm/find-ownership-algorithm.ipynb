# %% [markdown]
# # Les projets Open Source de Machine Learning ont ils des algorithmes qui est detenus par un seul contributeur?
#
# ## Préambule
#
#
# Pour étudier cette question nous avons défini des hypothèses et des métriques.
# ## Hypothèses :
# Après avoir constaté que dans le cadre des projets machine learning la plus part des temps qu'un fichier possède un seul algorithme(machine learning), alors nous avons posé ces différents hypothèses qui sont :
#     * La prémière hypothèse que nous avons faites est de dire que si un fichier a été développé par un seul contribiteur alors ce contributeur est l'unique propriètaire de ce algorithme.
#     * Pour pousser notre idée , nous avons défini l'hypothèse que si dans un fichier,il existe deux ou plusieurs contributeurs , de regarder le pourcentage de contribution de chaque contributeur est de dire s'il existe un contributeur avec un pourcentage de contribution superieur à 95 % alors ce contributeur est le propriètaire de cet algorithme.
# #### NB:
# Nous avons établi cette deuxième hypothèse après avoir constaté que dans les projets opens sources en générale , il peut existe plusieurs contributeurs dans un fichier, mais si on regarde en profondeur on peut y trouver que la grande majorité du fichier est faite par une seul personne , et que les autres contributeurs ont fixé des bugs, modifier ou supprimer une ligne,etc..
# ## Métriques :
#     * Le nombre de lignes par auteur
#     * Le pourcentage de contributions par auteur
# ## Projets :
# Pour cette questions nous avons étudier trois projets qui sont :
#     1. Keras (256 fichiers)
#     2. Scikit-learn (1180 fichiers)
#     3. Tensorflow (10136 fichiers)
#
# ## Démarches :
# Afin de répondre à la question, nous avons fait un programe nous permettant de parcourir un projet avec git blame, et nous produire à la sortie:
#     1. File : Nom du fichier
#     2. Othor[i] : Nom de l'auteur i (i représente le numero de l'auteur)
#     3. LineOthor[i] : Nombre de ligne de l'auteur i
#     4. Contribution[i] : Pourcentage de contribution de l'auteur i
#     5. File Lines : Nombre total de lignes du fichier
#     6. Learning : Est ce un algorithme d'apprentissage (Cette colonne est verifié que pour le projet Scikit-learn)
#     7. NbOthors : Nombre total de contributeur du fichier
#  ## Etude :
# Pour chacun de ces trois projets nous avons étudier les fichiers qui ont de 1 à 10 contributeurs, donc pour les resultats nous prendrons par nombre de contributeurs par fichier. Ces resultats se trouve dans le dossier DataResult.

# %%
# Let us import some awesome libraries!
import pandas as pd
import numpy as np
import math
import os

# Definition of some constants.
DATASETS_LOCATION = 'DataResult/'

# %% [markdown]
# # Fichier avec un seul contributeur

# %%
df = pd.read_csv(DATASETS_LOCATION + 'Keras/Owner1.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df1
# Out:
#                         File            Othor1  LineOthor1  Contribution1  \
# 2    \keras\legacy\models.py  Francois Chollet          31            100
# 1  \keras\engine\__init__.py  Francois Chollet           8            100
# 0       \keras\objectives.py  Francois Chollet           6            100
#
#    File Lines   Learning    NbOthors
# 2          31       False          1
# 1           8       False          1
# 0           6       False          1

# %%
df = pd.read_csv(DATASETS_LOCATION + 'ScikitLearn/Owner1.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df1
# Out:
#                                                 File              Othor1  \
# 7   scikit-learn\sklearn\utils\_unittest_backport.py      Kumar Ashutosh
# 6      scikit-learn\sklearn\preprocessing\_target.py  Guillaume Lemaitre
# 4  scikit-learn\sklearn\externals\joblib\_memory_...         Loic Esteve
# 3  scikit-learn\sklearn\externals\joblib\backport...         Loic Esteve
# 5  scikit-learn\sklearn\externals\joblib\_multipr...      Olivier Grisel
# 0                           scikit-learn\conftest.py         Loic Esteve
# 2         scikit-learn\sklearn\externals\__init__.py      Gael Varoquaux
# 1  scikit-learn\sklearn\cross_decomposition\__ini...      Sebastin Santy
#
#    LineOthor1  Contribution1  File Lines   Learning    NbOthors
# 7         224            100         224       False          1
# 6         223            100         223        True          1
# 4         105            100         105       False          1
# ...

# %%
df = pd.read_csv(DATASETS_LOCATION + 'Tensorflow/Owner1.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df1
# Out:
#                                                   File  \
# 121  tensorflow\contrib\kfac\python\ops\fisher_bloc...
# 101  tensorflow\contrib\gan\python\losses\python\lo...
# 271  tensorflow\contrib\timeseries\python\timeserie...
# 75   tensorflow\contrib\estimator\python\estimator\...
# 150  tensorflow\contrib\model_pruning\python\prunin...
# 342       tensorflow\python\training\checkpointable.py
# 71   tensorflow\contrib\estimator\python\estimator\...
# 133  tensorflow\contrib\layers\python\layers\rev_bl...
# 25   tensorflow\contrib\boosted_trees\lib\learner\b...
# 18   tensorflow\contrib\boosted_trees\estimator_bat...
# 279   tensorflow\contrib\tpu\python\tpu\tpu_context.py
# 128        tensorflow\contrib\kfac\python\ops\utils.py
# 338  tensorflow\python\profiler\internal\flops_regi...
# 9    tensorflow\contrib\bayesflow\python\ops\metrop...
# 67   tensorflow\contrib\eager\python\checkpointable...
# 7    tensorflow\contrib\bayesflow\python\ops\mcmc_d...
# ...

# %% [markdown]
# Ici on affiche seulement les 20 premiers fichiers sur les 353 au total avec un seul contributeur de façon décroissant

# %% [markdown]
# Nous constatons qu' avec l'yhpothèse d'un seul contributeur par fichier , on en trouve plus sur le(s) plus grand(s) projet(s) , dans notre cas on  trouve 3 pour Keras(256 fichiers),8 pour ScikitLearn(1180 fichiers) et enfin 353 pour Teansorflow(10 136 fichiers) qui est aussi le plus grand des trois en matière de nombre de fichier.

# %% [markdown]
# # Fichier avec trois Contributeurs

# %%
df = pd.read_csv(DATASETS_LOCATION + 'Keras/Owner3.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3'], ascending=False)
df2.head(10)
# Out:
#                                File              Othor1  LineOthor1  \
# 1          \keras\datasets\cifar.py    fchollet                  10
# 0     \keras\applications\nasnet.py  Francois Chollet            64
# 2  \keras\layers\cudnn_recurrent.py    Francois Chollet          16
#
#    Contribution1              Othor2  LineOthor2  Contribution2  \
# 1      27.027027    Francois Chollet          18      48.648649
# 0       9.756098  Somshubra Majumdar         591      90.091463
# 2       2.985075    François Chollet         519      96.828358
#
#                Othor3  LineOthor3  Contribution3  File Lines  Learning  \
# 1    Bohumír Zámečník          11      29.729730          37     False
# 0  Taehoon Lee                  3       0.457317         656     False
# 2    fchollet                   3       0.559701         536     False
#
#    NbOthors
# 1         3
# 0         3
# 2         3

# %%
df = pd.read_csv(DATASETS_LOCATION + 'ScikitLearn/Owner3.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3'], ascending=False)
df2.head(10)
# Out:
#                                                  File              Othor1  \
# 10  scikit-learn\sklearn\neural_network\_stochasti...          Glenn Qian
# 7   scikit-learn\sklearn\feature_selection\mutual_...  Nikolay Mayorov
# 5   scikit-learn\sklearn\externals\joblib\_paralle...      Olivier Grisel
# 1   scikit-learn\sklearn\externals\joblib\format_s...      Gael Varoquaux
# 9    scikit-learn\sklearn\model_selection\__init__.py      Raghav RV
# 6    scikit-learn\sklearn\feature_extraction\setup.py     Lars Buitinck
# 8       scikit-learn\sklearn\metrics\cluster\setup.py     Corey Lynch
# 0         scikit-learn\sklearn\decomposition\setup.py       Chyi-Kwei Yau
# 12                scikit-learn\sklearn\utils\bench.py  Fabian Pedregosa
# 3   scikit-learn\sklearn\externals\joblib\numpy_pi...      Olivier Grisel
#
#     LineOthor1  Contribution1              Othor2  LineOthor2  Contribution2  \
# 10         263      98.872180          Nelson Liu           2       0.751880
# ...

# %%
df = pd.read_csv(DATASETS_LOCATION + 'Tensorflow/Owner3.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3'], ascending=False)
df2
# Out:
#                                                   File  \
# 73   tensorflow\contrib\timeseries\python\timeserie...
# 23   tensorflow\contrib\factorization\python\ops\wa...
# 70   tensorflow\contrib\tensor_forest\client\random...
# 20        tensorflow\contrib\eager\python\evaluator.py
# 126       tensorflow\python\profiler\option_builder.py
# 87   tensorflow\python\estimator\warm_starting_util.py
# 28              tensorflow\contrib\gan\python\train.py
# 105  tensorflow\python\keras\_impl\keras\layers\loc...
# 86   tensorflow\python\debug\wrappers\local_cli_wra...
# 11   tensorflow\contrib\distributions\python\ops\de...
# 72   tensorflow\contrib\timeseries\python\timeserie...
# 3    tensorflow\contrib\cloud\python\ops\bigquery_r...
# 104  tensorflow\python\keras\_impl\keras\layers\con...
# 115          tensorflow\python\ops\confusion_matrix.py
# 110  tensorflow\python\keras\_impl\keras\utils\io_u...
# 117           tensorflow\python\ops\summary_op_util.py
# ...

# %% [markdown]
# # Fichier avec cinq Contributeurs

# %%
df = pd.read_csv(DATASETS_LOCATION + 'Keras/Owner5.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3','Contribution4','Contribution5'], ascending=False)
df2
# Out:
#                                          File                      Othor1  \
# 0                      \keras\initializers.py            Francois Chollet
# 1  \keras\applications\inception_resnet_v2.py            Yu-Yang Huang
# 4                   \keras\layers\__init__.py  Francois Chollet
# 3                    \keras\datasets\mnist.py            Francois Chollet
# 2                  \keras\datasets\cifar10.py           Francois Chollet
#
#    LineOthor1  Contribution1                      Othor2  LineOthor2  \
# 0         471      93.638171            Zhengtao Wang              7
# 1         352      92.388451            Taehoon Lee                3
# 4          43      78.181818  François Chollet                     3
# 3          19      67.857143            fchollet                   4
# 2          19      43.181818           fchollet                   14
#
#    Contribution2                      Othor3  LineOthor3  Contribution3  \
# ...

# %%
df = pd.read_csv(DATASETS_LOCATION + 'ScikitLearn/Owner5.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3','Contribution4','Contribution5'], ascending=False)
df2.head()
# Out:
#                                                  File                Othor1  \
# 2                scikit-learn\sklearn\metrics\base.py       Arnaud Joly
# 3   scikit-learn\sklearn\metrics\cluster\bicluster.py    Kemal Eren
# 5               scikit-learn\sklearn\neighbors\kde.py  Jake VanderPlas
# 4    scikit-learn\sklearn\mixture\bayesian_mixture.py    Thierry Guillemot
# 12        scikit-learn\sklearn\__check_build\setup.py       Virgile Fritsch
#
#     LineOthor1  Contribution1                Othor2  LineOthor2  \
# 2          114      91.935484       Lars Buitinck             2
# 3           73      84.883721    Vlad Niculae                 3
# 5          177      80.821918  Andreas Mueller               30
# 4          630      80.357143    Olivier Grisel             110
# 12          14      77.777778       Robert Layton             2
#
#     Contribution2                Othor3  LineOthor3  Contribution3  \
# 2        1.612903       Andreas Mueller           4       3.225806
# ...

# %%
df = pd.read_csv(DATASETS_LOCATION + 'Tensorflow/Owner5.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3','Contribution4','Contribution5'], ascending=False)
df2
# Out:
#                                                  File                  Othor1  \
# 42             tensorflow\python\debug\lib\stepper.py  Shanqing Cai
# 41       tensorflow\python\debug\cli\tensor_format.py          Shanqing Cai
# 4   tensorflow\contrib\distributions\python\ops\ve...  Joshua V. Dillon
# 73           tensorflow\python\training\adagrad_da.py  A. Unique TensorFlower
# 37      tensorflow\contrib\tpu\python\tpu\tpu_feed.py           Frank Chen
# 51       tensorflow\python\estimator\export\export.py  David Soergel
# 75     tensorflow\python\training\proximal_adagrad.py  A. Unique TensorFlower
# 27  tensorflow\contrib\seq2seq\python\ops\basic_de...  Eugene Brevdo
# 65  tensorflow\python\ops\linalg\linear_operator_f...  Ian Langmore
# 43  tensorflow\python\debug\wrappers\dumping_wrapp...  Shanqing Cai
# 64  tensorflow\python\ops\linalg\linear_operator_d...  Ian Langmore
# 78  tensorflow\tools\api\lib\python_object_to_prot...       Gunhan Gulsoy
# ...

# %% [markdown]
# # Fichier avec huit Contributeurs

# %%
df = pd.read_csv(DATASETS_LOCATION + 'Keras/Owner8.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3','Contribution4','Contribution5','Contribution6','Contribution7','Contribution8'], ascending=False)
df2.head()
# Out:
#                                   File                Othor1  LineOthor1  \
# 1  \keras\applications\inception_v3.py   Francois Chollet            372
# 2         \keras\applications\vgg19.py   Francois Chollet            165
# 5       \keras\utils\training_utils.py     Francois Chollet          148
# 4              \keras\legacy\layers.py  Francois Chollet             754
# 0               \keras\regularizers.py      Francois Chollet          59
#
#    Contribution1                Othor2  LineOthor2  Contribution2  \
# 1      91.400491   Dan Becker                   12       2.948403
# 2      81.683168   Dan Becker                   12       5.940594
# 5      78.306878     Vasilis Vryniotis           2       1.058201
# 4      67.201426  Daniel Høyer Iversen           2       0.178253
# 0      67.045455      Michael Oliver             2       2.272727
#
#                  Othor3  LineOthor3  Contribution3   ...    Contribution6  \
# ...

# %%
df = pd.read_csv(DATASETS_LOCATION + 'ScikitLearn/Owner8.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3','Contribution4','Contribution5','Contribution6','Contribution7','Contribution8'], ascending=False)
df2.head()
# Out:
#                                              File                    Othor1  \
# 6           scikit-learn\sklearn\neighbors\lof.py  Nicolas Goix
# 3    scikit-learn\sklearn\gaussian_process\gpc.py        Jan Hendrik Metzen
# 5  scikit-learn\sklearn\linear_model\theil_sen.py        Florian Wilhelm
# 0            scikit-learn\sklearn\kernel_ridge.py        Jan Hendrik Metzen
# 2  scikit-learn\sklearn\decomposition\__init__.py      Vlad Niculae
#
#    LineOthor1  Contribution1                    Othor2  LineOthor2  \
# 6         282      94.314381  Osaid Rehman Nasir                 4
# 3         695      94.046008        Sergei Lebedev               3
# 5         365      93.830334        Gael Varoquaux               5
# 0         162      87.567568        Mathieu Blondel              9
# 2          20      50.000000      Gilles Louppe                  4
#
#    Contribution2                    Othor3  LineOthor3  Contribution3  \
# ...

# %%
df = pd.read_csv(DATASETS_LOCATION + 'Tensorflow/Owner8.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3','Contribution4','Contribution5','Contribution6','Contribution7','Contribution8'], ascending=False)
df2.head()
# Out:
#                                                  File                  Othor1  \
# 3   tensorflow\contrib\labeled_tensor\python\ops\c...  Stephan Hoyer
# 10  tensorflow\contrib\metrics\python\ops\histogra...  A. Unique TensorFlower
# 15                tensorflow\python\layers\pooling.py  A. Unique TensorFlower
# 6   tensorflow\contrib\layers\python\layers\target...  A. Unique TensorFlower
# 4   tensorflow\contrib\layers\python\layers\initia...  A. Unique TensorFlower
#
#     LineOthor1  Contribution1                  Othor2  LineOthor2  \
# 3         1150      96.153846  A. Unique TensorFlower          33
# 10         212      87.242798  Martin Wicke                     3
# 15         570      83.946981  Alexandre Passos                20
# 6          424      80.761905  Zakaria Haque                   20
# 4          119      77.777778  Dan Ringwalt                     4
#
#     Contribution2                  Othor3  LineOthor3  Contribution3   ...     \
# ...

# %% [markdown]
# # Fichier avec dix Contributeurs

# %%
df = pd.read_csv(DATASETS_LOCATION + 'Keras/Owner10.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3','Contribution4','Contribution5','Contribution6','Contribution7','Contribution8','Contribution9','Contribution10'], ascending=False)
df2.head()
# Out:
#                                        File               Othor1  LineOthor1  \
# 1           \keras\applications\resnet50.py  Francois Chollet            240
# 4               \keras\utils\layer_utils.py    Francois Chollet          185
# 3  \keras\layers\convolutional_recurrent.py     Francois Chollet         400
# 0                     \keras\constraints.py     Francois Chollet         112
# 2                \keras\backend\__init__.py     Francois Chollet          54
#
#    Contribution1               Othor2  LineOthor2  Contribution2  \
# 1      82.474227  Dan Becker                   12       4.123711
# 4      79.059829    fchollet                    2       0.854701
# 3      70.796460     JM Arbona                 97      17.168142
# 0      60.540541     Michael Oliver            19      10.270270
# 2      52.941176     Liang-Chi Hsieh            6       5.882353
#
#                 Othor3  LineOthor3  Contribution3   ...    Contribution8  \
# ...

# %%
df = pd.read_csv(DATASETS_LOCATION + 'ScikitLearn/Owner10.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3','Contribution4','Contribution5','Contribution6','Contribution7','Contribution8','Contribution9','Contribution10'], ascending=False)
df2.head()
# Out:
#                                                 File  \
# 2            scikit-learn\sklearn\manifold\isomap.py
# 5     scikit-learn\sklearn\preprocessing\__init__.py
# 3   scikit-learn\sklearn\mixture\gaussian_mixture.py
# 1           scikit-learn\sklearn\datasets\covtype.py
# 0  scikit-learn\sklearn\cluster\_feature_agglomer...
#
#                      Othor1  LineOthor1  Contribution1  \
# 2          Jake VanderPlas          142      64.253394
# 5     Nicolas Trésegnie              37      54.411765
# 3        Thierry                    406      54.205607
# 1  Lars Buitinck                     66      53.658537
# 0        Vincent Michel              30      37.037037
#
#                      Othor2  LineOthor2  Contribution2  \
# 2          Robert Layton              2       0.904977
# 5     Lars Buitinck                   2       2.941176
# 3        Thierry Guillemot          301      40.186916
# 1  Ilambharathi Kanniah              16      13.008130
# ...

# %%
df = pd.read_csv(DATASETS_LOCATION + 'Tensorflow/Owner10.csv', sep=';')
df1 = df.sort_values(by='File Lines', ascending=False)
df2 = df1.sort_values(by=['Contribution1','Contribution2', 'Contribution3','Contribution4','Contribution5','Contribution6','Contribution7','Contribution8','Contribution9','Contribution10'], ascending=False)
df2.head()
# Out:
#                                                  File                  Othor1  \
# 7                 tensorflow\python\ops\lookup_ops.py  Yutaka Leon
# 6                 tensorflow\python\ops\linalg_ops.py  A. Unique TensorFlower
# 4   tensorflow\contrib\learn\python\learn\ops\seq2...  A. Unique TensorFlower
# 3   tensorflow\contrib\learn\python\learn\estimato...  A. Unique TensorFlower
# 10               tensorflow\python\summary\summary.py  Dan Mané
#
#     LineOthor1  Contribution1                  Othor2  LineOthor2  \
# 7         1161      89.239047  A. Unique TensorFlower         105
# 6          459      79.826087  Manjunath Kudlur                22
# 4          114      76.510067  Vijay Vasudevan                 13
# 3          650      67.497404  Vijay Vasudevan                  6
# 10         244      67.403315  A. Unique TensorFlower          42
#
#     Contribution2                  Othor3  LineOthor3  Contribution3   ...     \
# ...
